# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid.axislines import Subplot
import numpy as np
import math
import glob
import re
#
figuresize = 8
plt.rcParams['figure.figsize'] = figuresize, figuresize
plt.rcParams['figure.dpi'] = 100
plt.rcParams['font.size'] = 20
plt.rcParams['font.family'] = "serif"
plt.rcParams['text.usetex'] = "True"

# %%
pitch = 1.26

# %%
fig = plt.figure()

ax = Subplot(fig, 111, aspect='equal')
fig.add_subplot(ax)

ax.axis["right"].set_visible(False)
ax.axis["top"].set_visible(False)
plt.axis((-pitch/2,pitch/2,-pitch/2,pitch/2))

plt.title("Pinmesh 1")

# pinMesh 1 cyl 0.540 0.62 / 1.26 / 3.57 / 5 2 / 5*8 2*8 8 / 1   !Pin mesh 

circle1=plt.Circle((0,0), 0.54, edgecolor='k', facecolor="none", alpha=1, linestyle='dotted'); plt.gcf().gca().add_artist(circle1)
circle2=plt.Circle((0,0), 0.62, edgecolor='k', facecolor="none", alpha=1, linestyle='dotted'); plt.gcf().gca().add_artist(circle2)

#plt.plot([pitch/2,pitch/2], [-pitch/2,pitch/2], 'k:', lw=1)

plt.show()
